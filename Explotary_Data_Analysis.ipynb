# %% [markdown]
# #### Importing The Library's

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# #### Reading CSV Files

# %%
df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")
# Out:
# C:\Users\venkatraman.b\AppData\Local\Temp\ipykernel_15168\569291826.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")

# %% [markdown]
# #### Displaying The First Five Data's In The CSV File

# %%
df.head()
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance        Athlete club  \
# 0                         22           4:51:39 h               Tnfrc
# 1                         22           5:15:45 h  Roberto Echeverría
# 2                         22           5:16:44 h   Puro Trail Osorno
# 3                         22           5:34:13 h            Columbia
# 4                         22           5:54:14 h      Baguales Trail
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# ...

# %% [markdown]
# #### Checking The Shape of the CSV File

# %%
df.shape
# Out:
# (7461195, 13)

# %% [markdown]
# #### Checking the data types in csv files

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %% [markdown]
# #### Getting the data only contain 50 KM and 50 Mile in the year 2020

# %%
year_2020 = df[(df["Event distance/length"].isin(["50km","50mi"])) & (df["Year of event"] == 2020)]
year_2020.head()
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
#
#          Event number of finishers Athlete performance Athlete club  \
# 2538571                         38           7:34:19 h          日本隊
# 2538572                         38           7:43:50 h          NaN
# 2538573                         38           8:04:40 h          NaN
# ...

# %% [markdown]
# #### Splitting The Event name column and seperating the country's from the result

# %% [markdown]
# ##### Spliting the country name

# %%
country_names = df["Event name"].str.split("(").str.get(1).str.split(")").str.get(0)
country_names
# Out:
# 0          CHI
# 1          CHI
# 2          CHI
# 3          CHI
# 4          CHI
#           ...
# 7461190    FRA
# 7461191    FRA
# 7461192    HUN
# 7461193    HUN
# 7461194    HUN
# Name: Event name, Length: 7461195, dtype: object

# %%
country_names == "USA"
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 7461190    False
# 7461191    False
# 7461192    False
# 7461193    False
# 7461194    False
# Name: Event name, Length: 7461195, dtype: bool

# %% [markdown]
# #### Combining both the logic and Displaying the result

# %%
df[(df["Event distance/length"].isin(["50km","50mi"])) & (df["Year of event"] == 2020) & (df["Event name"].str.split("(").str.get(1).str.split(")").str.get(0) == "USA")]
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# ...                ...         ...
# 2760957           2020  03.10.2020
# 2760958           2020  03.10.2020
# 2760959           2020  03.10.2020
# 2760960           2020  03.10.2020
# 2760961           2020  03.10.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...

# %%
df2 = df[(df["Event distance/length"].isin(["50km","50mi"])) & (df["Year of event"] == 2020) & (df["Event name"].str.split("(").str.get(1).str.split(")").str.get(0) == "USA")]
df2.head()
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
#
#          Event number of finishers Athlete performance  \
# 2539945                         20           3:17:55 h
# 2539946                         20           4:02:32 h
# 2539947                         20           4:07:57 h
# 2539948                         20           4:22:02 h
# ...

# %% [markdown]
# #### Displaying the shape of df2 Dataframe

# %%
df2.shape
# Out:
# (26090, 13)

# %% [markdown]
# #### Removing country name in Event Name column

# %%
df2["Event name"].str.split("(").str.get(0)
# Out:
# 2539945    West Seattle Beach Run - Winter Edition
# 2539946    West Seattle Beach Run - Winter Edition
# 2539947    West Seattle Beach Run - Winter Edition
# 2539948    West Seattle Beach Run - Winter Edition
# 2539949    West Seattle Beach Run - Winter Edition
#                              ...
# 2760957     Yankee Springs Fall Trail Run Festival
# 2760958     Yankee Springs Fall Trail Run Festival
# 2760959     Yankee Springs Fall Trail Run Festival
# 2760960     Yankee Springs Fall Trail Run Festival
# 2760961     Yankee Springs Fall Trail Run Festival
# Name: Event name, Length: 26090, dtype: object

# %%
df2["Event name"] = df2["Event name"].str.split("(").str.get(0)
# Out:
# C:\Users\venkatraman.b\AppData\Local\Temp\ipykernel_15168\3464257636.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Event name"] = df2["Event name"].str.split("(").str.get(0)

# %%
df2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20           3:17:55 h
# 2539946                  50km                         20           4:02:32 h
# 2539947                  50km                         20           4:07:57 h
# 2539948                  50km                         20           4:22:02 h
# 2539949                  50km                         20           4:27:34 h
#
# ...

# %% [markdown]
# #### Calculating the Athelet age for 2025

# %%
df2["Athelet_Age"] = 2025 - df2["Athlete year of birth"]
df2["Athelet_Age"].head()
# Out:
# C:\Users\venkatraman.b\AppData\Local\Temp\ipykernel_15168\640266928.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Athelet_Age"] = 2025 - df2["Athlete year of birth"]
# 2539945    34.0
# 2539946    44.0
# 2539947    26.0
# 2539948    42.0
# 2539949    48.0
# Name: Athelet_Age, dtype: float64

# %% [markdown]
# #### Removing h from Athelet perfomance column

# %%
df2["Athlete performance"] = df2["Athlete performance"].str.split('h').str.get(0)
df2.head()
# Out:
# C:\Users\venkatraman.b\AppData\Local\Temp\ipykernel_15168\3096109847.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Athlete performance"] = df2["Athlete performance"].str.split('h').str.get(0)
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
# ...

# %% [markdown]
# #### Droping unwanted columns in the dataset

# %% [markdown]
# ##### Dropping these columns : Athlete club, Athlete country, Athlete year of birth, Athlete age category

# %%
df2 = df2.drop(["Athlete club","Athlete country","Athlete year of birth","Athlete age category"], axis = 1)

# %%
df2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20            3:17:55
# 2539946                  50km                         20            4:02:32
# 2539947                  50km                         20            4:07:57
# 2539948                  50km                         20            4:22:02
# 2539949                  50km                         20            4:27:34
#
# ...

# %% [markdown]
# #### Dropping na values from the dataset

# %%
df2.isna().sum()
# Out:
# Year of event                  0
# Event dates                    0
# Event name                     0
# Event distance/length          0
# Event number of finishers      0
# Athlete performance            0
# Athlete gender                 0
# Athlete average speed          0
# Athlete ID                     0
# Athelet_Age                  233
# dtype: int64

# %%
df2 = df2.dropna()

# %%
df2.isna().sum()
# Out:
# Year of event                0
# Event dates                  0
# Event name                   0
# Event distance/length        0
# Event number of finishers    0
# Athlete performance          0
# Athlete gender               0
# Athlete average speed        0
# Athlete ID                   0
# Athelet_Age                  0
# dtype: int64

# %% [markdown]
# #### Checking the duplicate values in dataset

# %%
df2[df2.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, Athelet_Age]
# Index: []

# %% [markdown]
# #### Reseting the Index

# %%
df2.reset_index(drop = True)
# Out:
#        Year of event Event dates                                Event name  \
# 0               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 1               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 3               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 4               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...              ...         ...                                       ...
# 25852           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25853           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25854           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25855           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25856           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
#       Event distance/length  Event number of finishers Athlete performance  \
# ...

# %% [markdown]
# #### Reframeing the data types

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed         object
# Athlete ID                     int64
# Athelet_Age                  float64
# dtype: object

# %%
df2["Athlete average speed"] = df2["Athlete average speed"].astype(float)

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# Athelet_Age                  float64
# dtype: object

# %% [markdown]
# #### Renaming the column names

# %%
df2 = df2.rename(columns = {'Year of event':'Year',
                 'Event dates':'Race_day',
                 'Event name':'Race_name',
                 'Event distance/length':'Event_distance/length',
                 'Event number of finishers':'Finisher_count',
                 'Athlete performance':'Athlete_performance',
                 'Athlete gender': 'Athlete_gender',
                 'Athlete average speed':'Athlete_average_speed',
                 'Athlete ID':'Athlete_ID',
                 'Athelet_Age':'Athelet_Age'})

# %%
df2.head()
# Out:
#          Year    Race_day                                 Race_name  \
# 2539945  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949  2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event_distance/length  Finisher_count Athlete_performance  \
# 2539945                  50km              20            3:17:55
# 2539946                  50km              20            4:02:32
# 2539947                  50km              20            4:07:57
# 2539948                  50km              20            4:22:02
# 2539949                  50km              20            4:27:34
#
#         Athlete_gender  Athlete_average_speed  Athlete_ID  Athelet_Age
# 2539945              M                 15.158       71287         34.0
# ...

# %% [markdown]
# #### Reordering the column

# %%
df3 = df2[['Race_day','Race_name','Event_distance/length','Finisher_count','Athlete_ID','Athlete_gender','Athlete_performance','Athlete_average_speed','Athelet_Age','Year']]

# %%
df3.head()
# Out:
#            Race_day                                 Race_name  \
# 2539945  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event_distance/length  Finisher_count  Athlete_ID Athlete_gender  \
# 2539945                  50km              20       71287              M
# 2539946                  50km              20      629508              M
# 2539947                  50km              20       64838              M
# 2539948                  50km              20      704450              M
# 2539949                  50km              20      810281              M
#
#         Athlete_performance  Athlete_average_speed  Athelet_Age  Year
# 2539945            3:17:55                  15.158         34.0  2020
# ...

# %% [markdown]
# #### Finding the races from Everglades

# %%
df3[df3["Race_name"] == "Everglades 50 Mile Ultra Run "].head()
# Out:
#            Race_day                      Race_name Event_distance/length  \
# 2591476  14.03.2020  Everglades 50 Mile Ultra Run                   50mi
# 2591477  14.03.2020  Everglades 50 Mile Ultra Run                   50mi
# 2591478  14.03.2020  Everglades 50 Mile Ultra Run                   50mi
# 2591479  14.03.2020  Everglades 50 Mile Ultra Run                   50mi
# 2591480  14.03.2020  Everglades 50 Mile Ultra Run                   50mi
#
#          Finisher_count  Athlete_ID Athlete_gender Athlete_performance  \
# 2591476              40      820757              M            8:31:39
# 2591477              40       46432              M            8:31:48
# 2591478              40      813617              M            8:34:43
# 2591479              40      820758              M            9:07:35
# 2591480              40      647115              M            9:15:32
#
#          Athlete_average_speed  Athelet_Age  Year
# 2591476                  9.436         32.0  2020
# ...

# %%
df3[df3["Athlete_ID"] == 222509]
# Out:
#            Race_day                      Race_name Event_distance/length  \
# 2591482  14.03.2020  Everglades 50 Mile Ultra Run                   50mi
# 2616900  22.02.2020       Manasota Track Club 50K                   50km
#
#          Finisher_count  Athlete_ID Athlete_gender Athlete_performance  \
# 2591482              40      222509              M            9:19:10
# 2616900              36      222509              M            4:49:16
#
#          Athlete_average_speed  Athelet_Age  Year
# 2591482                  8.634         28.0  2020
# 2616900                 10.371         28.0  2020

# %% [markdown]
# ## Chart's And Graph

# %%
sns.histplot(df3['Event_distance/length'])
# Out:
# <Axes: xlabel='Event_distance/length', ylabel='Count'>

# %%
sns.histplot(df3, x = 'Event_distance/length', hue = 'Athlete_gender')
# Out:
# <Axes: xlabel='Event_distance/length', ylabel='Count'>

# %%
sns.displot(df3[df3['Event_distance/length'] == '50mi']['Athlete_average_speed'])

# %%
sns.violinplot(df3, x = 'Event_distance/length', y = 'Athlete_average_speed', hue = 'Athlete_gender', split = True, inner = 'quart', linewidth = 1)
# Out:
# <Axes: xlabel='Event_distance/length', ylabel='Athlete_average_speed'>

# %%
sns.lmplot(df3, x = 'Athelet_Age', y = 'Athlete_average_speed', hue = 'Athlete_gender')
